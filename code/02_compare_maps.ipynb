# %% [markdown]
# ## Comparando os mapas Inventário x MapBiomas

# %% [markdown]
# ## Importar os pacotes que serão usados

# %%
from osgeo import gdal, osr
import psutil
import sys
import numpy as np
import rasterio
from sklearn.metrics import confusion_matrix
from rasterio.plot import show
import pandas as pd
from numpy import savetxt

# %%
# # Carrega os arquivos
# dataset1 = '../dados/inventario_v4_2016/inventario_biomas_rasters/inventario_amazonia_byte.tif'
# dataset2 = '../dados/mapbiomas_v7_2016/biomas/mapbiomas_amazonia_byte.tif'

# with rasterio.open(dataset1) as src:
#     #show(src)
#     mapa1 = src.read()

# with rasterio.open(dataset2) as src:
#     #show(src)
#     mapa2 = src.read()

# # Convertendo os mapas em um array de uma só linha    
# mapa1 = mapa1.reshape(-1)
# mapa2 = mapa2.reshape(-1)

# print(len(mapa1))

# # Tabulação cruzada
# # tabulacao_cruzada = confusion_matrix(mapa1, mapa2)
# # print(tabulacao_cruzada)

# mapa1 = None
# mapa2 = None

# %% [markdown]
# ## Fazer as checagens entre os mapas

# %% [markdown]
# Conferir o número de linhas, colunas, a projeção e a resolução de ambos os mapas e verificar se são coincidentes.

# %%
# Carrega os arquivos
dataset1 = gdal.Open('../dados/inventario_v4_2016/inventario_biomas_rasters/inventario_amazonia_byte.tif')
dataset2 = gdal.Open('../dados/mapbiomas_v7_2016/biomas/mapbiomas_amazonia_byte.tif')

#dataset1.SetProjection("EPSG:4674")

# verifica se as dimensões dos arquivos são iguais
if dataset1.RasterXSize != dataset2.RasterXSize or dataset1.RasterYSize != dataset2.RasterYSize:
    print("ERRO: As dimensões dos arquivos são diferentes.")
    sys.exit(1)

# verifica se as projeções dos arquivos são iguais
if osr.SpatialReference(dataset1.GetProjection()).GetAttrValue('AUTHORITY', 1) != osr.SpatialReference(dataset2.GetProjection()).GetAttrValue('AUTHORITY', 1):
    print("ERRO: As projeções dos arquivos são diferentes.")
    sys.exit(1)

# verifica se as resoluções dos arquivos são iguais
if round(dataset1.GetGeoTransform()[1], 7) != round(dataset1.GetGeoTransform()[1], 7):
    print("ERRO: As resoluções dos arquivos são diferentes.")
    sys.exit(1)

# se tudo estiver correto, exibe uma mensagem de confirmação
print("Os arquivos têm as mesmas dimensões, projeção e resolução.")
# Out:
# Os arquivos têm as mesmas dimensões, projeção e resolução.

# %% [markdown]
# ## Checagem de memória disponível

# %% [markdown]
# Caso os mapas satifaçam as checagens, será feita uma verificação de memória disponível que será alocada para o processo de comparação dos mapas.

# %%
# Verifica se é possível obter a quantidade de memória disponível em tempo de execução
try:
    available_memory = psutil.virtual_memory().available

    # Define o tamanho máximo do bloco em bytes
    max_block_size_bytes = available_memory * 0.2  # 80% da memória disponível
    
except:
    # Caso contrário, define uma quantidade fixa de memória disponível
    available_memory = 1024 * 1024 * 1024  # 1 GB em bytes

    max_block_size_bytes = available_memory

print("Memória disponível:", available_memory, "\n")
print("Memória alocada:", max_block_size_bytes, "\n")

# Calcula o tamanho máximo do bloco em pixels
side_block = int((max_block_size_bytes / 2) ** 0.5)  # dividido por 2, pois são dois mapas

print("Lateral do bloco:", side_block)
# Out:
# Memória disponível: 6080663552
#
# Memória alocada: 1216132710.4
#
# Lateral do bloco: 24659

# %% [markdown]
# ## Comparação dos mapas em pequenos batches

# %%
# obtém as dimensões dos arquivos
cols = dataset1.RasterXSize
rows = dataset1.RasterYSize
projection = dataset1.GetProjection()
geotransform = dataset1.GetGeoTransform()

print("Linhas, colunas e tamanho total:")
print(cols, rows, cols*rows, "\n")

num_blocos = 7

print("Altura e Largura do bloco")
step_col = int(cols/num_blocos)
step_row = int(rows/num_blocos)

print(step_col, step_row, "\n")

lista_classes = {}

for i in range(0, rows, step_row):
    for j in range(0, cols, step_col):

        # calcula o tamanho do bloco para esta parte
        print(f"Bloco_{i}_{j}", i*j)
        width = min(step_col, cols - j)
        height = min(step_row, rows - i)

        # le os blocos com os tamanhos determinados acima
        block1 = dataset1.ReadAsArray(j, i, xsize=width, ysize=height)
        block1 = block1.reshape(-1)

        block2 = dataset2.ReadAsArray(j, i, xsize=width, ysize=height)
        block2 = block2.reshape(-1)

        # calcula os valores de pixel unicos de cada mapa
        classes1 = np.unique(block1)
        classes2 = np.unique(block2)

        # concatena os valores e gera a lista de classes
        classes = np.unique(np.concatenate((classes1, classes2)))

        lista_classes[f"{i}_{j}"] = list(classes)

        #print("Iniciando matriz de confusao")
        block_confusion_matrix = confusion_matrix(block1, block2, labels=classes)
        print("Salvando tabulação cruzada referente ao bloco de altura", i, "e largura", j, "\n")

        # save to csv file
        savetxt(f'../confusion_matrix/amazonia/amazonia_{i}_{j}.csv', block_confusion_matrix, delimiter=',')

        #print(classes1, "\n", classes2, "\n")
        #print(classes)
# Out:
# Linhas, colunas e tamanho total:
# 112808 80069 9032423752
#
# Altura e Largura do bloco
# 16115 11438
#
# Bloco_0_0 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 0
#
# Bloco_0_16115 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 16115
#
# Bloco_0_32230 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 32230
#
# Bloco_0_48345 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 48345
#
# Bloco_0_64460 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 64460
#
# Bloco_0_80575 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 80575
#
# Bloco_0_96690 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 96690
#
# Bloco_0_112805 0
# Salvando tabulação cruzada referente ao bloco de altura 0 e largura 112805
#
# Bloco_11438_0 0
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 0
#
# Bloco_11438_16115 184323370
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 16115
#
# Bloco_11438_32230 368646740
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 32230
#
# Bloco_11438_48345 552970110
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 48345
#
# Bloco_11438_64460 737293480
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 64460
#
# Bloco_11438_80575 921616850
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 80575
#
# Bloco_11438_96690 1105940220
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 96690
#
# Bloco_11438_112805 1290263590
# Salvando tabulação cruzada referente ao bloco de altura 11438 e largura 112805
#
# Bloco_22876_0 0
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 0
#
# Bloco_22876_16115 368646740
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 16115
#
# Bloco_22876_32230 737293480
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 32230
#
# Bloco_22876_48345 1105940220
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 48345
#
# Bloco_22876_64460 1474586960
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 64460
#
# Bloco_22876_80575 1843233700
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 80575
#
# Bloco_22876_96690 2211880440
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 96690
#
# Bloco_22876_112805 2580527180
# Salvando tabulação cruzada referente ao bloco de altura 22876 e largura 112805
#
# Bloco_34314_0 0
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 0
#
# Bloco_34314_16115 552970110
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 16115
#
# Bloco_34314_32230 1105940220
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 32230
#
# Bloco_34314_48345 1658910330
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 48345
#
# Bloco_34314_64460 2211880440
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 64460
#
# Bloco_34314_80575 2764850550
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 80575
#
# Bloco_34314_96690 3317820660
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 96690
#
# Bloco_34314_112805 3870790770
# Salvando tabulação cruzada referente ao bloco de altura 34314 e largura 112805
#
# Bloco_45752_0 0
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 0
#
# Bloco_45752_16115 737293480
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 16115
#
# Bloco_45752_32230 1474586960
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 32230
#
# Bloco_45752_48345 2211880440
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 48345
#
# Bloco_45752_64460 2949173920
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 64460
#
# Bloco_45752_80575 3686467400
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 80575
#
# Bloco_45752_96690 4423760880
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 96690
#
# Bloco_45752_112805 5161054360
# Salvando tabulação cruzada referente ao bloco de altura 45752 e largura 112805
#
# Bloco_57190_0 0
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 0
#
# Bloco_57190_16115 921616850
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 16115
#
# Bloco_57190_32230 1843233700
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 32230
#
# Bloco_57190_48345 2764850550
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 48345
#
# Bloco_57190_64460 3686467400
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 64460
#
# Bloco_57190_80575 4608084250
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 80575
#
# Bloco_57190_96690 5529701100
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 96690
#
# Bloco_57190_112805 6451317950
# Salvando tabulação cruzada referente ao bloco de altura 57190 e largura 112805
#
# Bloco_68628_0 0
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 0
#
# Bloco_68628_16115 1105940220
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 16115
#
# Bloco_68628_32230 2211880440
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 32230
#
# Bloco_68628_48345 3317820660
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 48345
#
# Bloco_68628_64460 4423760880
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 64460
#
# Bloco_68628_80575 5529701100
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 80575
#
# Bloco_68628_96690 6635641320
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 96690
#
# Bloco_68628_112805 7741581540
# Salvando tabulação cruzada referente ao bloco de altura 68628 e largura 112805
#
# Bloco_80066_0 0
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 0
#
# Bloco_80066_16115 1290263590
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 16115
#
# Bloco_80066_32230 2580527180
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 32230
#
# Bloco_80066_48345 3870790770
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 48345
#
# Bloco_80066_64460 5161054360
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 64460
#
# Bloco_80066_80575 6451317950
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 80575
#
# Bloco_80066_96690 7741581540
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 96690
#
# Bloco_80066_112805 9031845130
# Salvando tabulação cruzada referente ao bloco de altura 80066 e largura 112805

# %%
import json
import numpy as np
from datetime import date, datetime, timedelta

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.bool_):
            return bool(obj)
        if isinstance(obj, (np.floating, np.complexfloating)):
            return float(obj)
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, np.string_):
            return str(obj)
        if isinstance(obj, (datetime, date)):
            return obj.isoformat()
        if isinstance(obj, timedelta):
            return str(obj)
        return super(NpEncoder, self).default(obj)

# %%
import json
with open('../confusion_matrix/amazonia/lista_classes.txt', 'w') as fout:
    fout.write(json.dumps(lista_classes, cls=NpEncoder, indent=2))
